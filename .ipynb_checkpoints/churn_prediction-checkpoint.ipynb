# %% [markdown]
# # Bank Customer Churn Prediction Using ANN:

# %% [markdown]
# **Importing Required Libraries:**

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = [10, 5]

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Bank_Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# **FirstofAll Lets remove some Unwanted columns from the dataset**

# %%
df.drop(['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace=True)
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
# Finding Missing Values

df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# **We are checking how much a column has all the values. As this can be done with only numerical column so we ignore the categorical columns**

# %%
columns = [col for col in df.columns if df[col].dtype != 'O']
df[columns].describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# min        0.00000        0.000000        11.580000      0.000000
# 25%        0.00000        0.000000     51002.110000      0.000000
# 50%        1.00000        1.000000    100193.915000      0.000000
# 75%        1.00000        1.000000    149388.247500      0.000000
# max        1.00000        1.000000    199992.480000      1.000000

# %% [markdown]
# **Check How our Dataset looks? Is it Balanced or Imbalance?**

# %%
sns.set_theme(style="darkgrid")
sns.countplot(df['Exited'], palette='Set1')
plt.xlabel('Customers Exit or Not', size = 15)
plt.show()

# %%
customer_not_exited = df[df.Exited == 0]
customer_exited = df[df.Exited == 1]

# %%
print(customer_not_exited.shape, customer_exited.shape)
# Out:
# (7963, 11) (2037, 11)

# %% [markdown]
# **We can see a dataset Imbalanced, so need to use some technique to make it Balanced. However, we can do it later**

# %% [markdown]
# # **Data Visualisations**

# %%
exited = df[df.Exited == 1].Tenure
not_exited = df[df.Exited == 0].Tenure

# %%
plt.hist([exited, not_exited], label = ['Yes', 'No'])
plt.xlabel('Tenure', color = 'r')
plt.ylabel('Number of Customers', color = 'green')
plt.title('Customers Loyalty', color = 'magenta')
plt.legend()
plt.show()

# %% [markdown]
# **By looking this graph we can say that If customer stays mrore than 5 months they likely happy with the service of bank**

# %%
sns.countplot(df['Geography'], data = df, palette='Paired')
plt.title('Bank-Customers from Each Country', size = 20, color = 'indigo')
plt.xlabel('Countries', size = 15, color = 'coral')
plt.ylabel('Number of Customers', size=15, color = 'peru')
plt.show()

# %%
sns.countplot(df['Gender'],hue=df['Exited'], palette='husl')
plt.legend(labels=['Not_Exited', 'Exited'])
plt.title('Gender ratio in Churn-prediction', size = 20, color = 'crimson')
plt.xlabel('Gender', size = 15, color = 'sienna')
plt.ylabel('Number of Customers', size=15, color = 'salmon')
plt.show()

# %%
# Check how many Customers are actived and still they want to move to another bank?

sns.countplot('IsActiveMember',hue = 'Exited', data=df, palette='hls')
plt.legend(labels=['Not_Exited', 'Exited'])
plt.title('Members Activity in Bank', size = 20, color = 'teal')
plt.xlabel('Active Members', size = 15, color = 'royalblue')
plt.ylabel('Number of Customers', size=15, color = 'orange')
plt.show()

# %% [markdown]
# **Will check how many columns are categorical and we will change into numerical data**

# %%
for col in df.columns:
    if df[col].dtype == 'O':
        print(f'{col}: {df[col].unique()}')
# Out:
# Geography: ['France' 'Spain' 'Germany']
# Gender: ['Female' 'Male']

# %% [markdown]
# **Unique values are less in a each categorical column so we won't use OHE or LabelEncoding.We can do it with replace function.**

# %%
df['Geography'] = df['Geography'].replace({'France': 0, 'Spain': 1, 'Germany': 2})
df['Gender'] = df['Gender'].replace({'Female': 0, 'Male': 1})

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          1       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          1       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# **Now, We have all Numerical Data so,we can divide the dataset into X, Y. So, In X we take Independent Features and in Y we take our Target class, which is Exited**

# %%
X = df.drop('Exited',axis=1)
Y = df['Exited']

# %%
X.shape, Y.shape
# Out:
# ((10000, 10), (10000,))

# %% [markdown]
# **So,Here we perform Oversampling technique for making Balanced Dataset,which basically make more data within the existing data,for the lower data class so, that both target_class comes on a same page and we can make prediction better. Although, You can also use Undersampling technique but, in that the chances of data loss will be high, hence we used OverSampling here**

# %%
from imblearn.combine import SMOTETomek
smk = SMOTETomek(random_state=42)

# %%
X,Y = smk.fit_resample(X, Y)

# %%
X.shape, Y.shape
# Out:
# ((13778, 10), (13778,))

# %%
sns.set_theme(style="darkgrid")
sns.countplot(Y, palette='Set1')
plt.xlabel('Customers Exit or Not', size = 15)
plt.show()

# %% [markdown]
# **Finally, we make our Dataset Balanced**

# %%
X
# Out:
#        CreditScore  Geography  Gender  Age  Tenure        Balance  \
# 0              619          0       0   42       2       0.000000
# 1              608          1       0   41       1   83807.860000
# 2              502          0       0   42       8  159660.800000
# 3              699          0       0   39       1       0.000000
# 4              850          1       0   43       2  125510.820000
# ...            ...        ...     ...  ...     ...            ...
# 13773          664          0       0   51       7  122675.546491
# 13774          807          0       0   36       9       0.000000
# 13775          773          2       0   47       5  108732.431561
# 13776          465          2       0   56       7  127070.846317
# 13777          603          2       0   32       3  102755.340078
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0                  1          1               1    101348.880000
# 1                  1          0               1    112542.580000
# 2                  3          1               0    113931.570000
# 3                  2          0               0     93826.630000
# 4                  1          1               1     79084.100000
# ...              ...        ...             ...              ...
# 13773              2          0               1    169402.890505
# 13774              1          1               0      4952.388026
# 13775              1          1               0    184555.335538
# 13776              1          1               0     51834.800300
# 13777              2          0               0    189755.014496
#
# [13778 rows x 10 columns]

# %% [markdown]
# **Here, we see many columns have various values, so in order to get good accuracy we need to do scaling on these columns so that every columns values falls between 0 to 1**

# %%
cols_to_scale = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X[cols_to_scale] = scaler.fit_transform(X[cols_to_scale])

# %%
X
# Out:
#        CreditScore  Geography  Gender       Age  Tenure   Balance  \
# 0            0.538          0       0  0.324324     0.2  0.000000
# 1            0.516          1       0  0.310811     0.1  0.334031
# 2            0.304          0       0  0.324324     0.8  0.636357
# 3            0.698          0       0  0.283784     0.1  0.000000
# 4            1.000          1       0  0.337838     0.2  0.500246
# ...            ...        ...     ...       ...     ...       ...
# 13773        0.628          0       0  0.445946     0.7  0.488946
# 13774        0.914          0       0  0.243243     0.9  0.000000
# 13775        0.846          2       0  0.391892     0.5  0.433373
# 13776        0.230          2       0  0.513514     0.7  0.506464
# 13777        0.506          2       0  0.189189     0.3  0.409550
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0           0.000000          1               1         0.506735
# 1           0.000000          0               1         0.562709
# 2           0.666667          1               0         0.569654
# 3           0.333333          0               0         0.469120
# 4           0.000000          1               1         0.395400
# ...              ...        ...             ...              ...
# 13773       0.333333          0               1         0.847037
# 13774       0.000000          1               0         0.024706
# 13775       0.000000          1               0         0.922807
# 13776       0.000000          1               0         0.259141
# 13777       0.333333          0               0         0.948808
#
# [13778 rows x 10 columns]

# %% [markdown]
# # Model Training Using ANN:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((11022, 10), (2756, 10))

# %%
model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(10,), activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(14, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(1, activation='sigmoid')   
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',      # As,we have Binary Prediction, we used this loss func
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.6473 - accuracy: 0.6234
# Epoch 2/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.5214 - accuracy: 0.7514
# Epoch 3/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4956 - accuracy: 0.7643
# Epoch 4/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4879 - accuracy: 0.7702
# Epoch 5/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4740 - accuracy: 0.7753
# Epoch 6/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4672 - accuracy: 0.7780
# Epoch 7/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4671 - accuracy: 0.7785
# Epoch 8/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4664 - accuracy: 0.7783
# Epoch 9/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4561 - accuracy: 0.7796
# Epoch 10/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4418 - accuracy: 0.7902
# Epoch 11/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4531 - accuracy: 0.7860
# Epoch 12/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4399 - accuracy: 0.7918
# Epoch 13/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4352 - accuracy: 0.7911
# Epoch 14/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4414 - accuracy: 0.7928
# Epoch 15/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4226 - accuracy: 0.8080
# Epoch 16/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4315 - accuracy: 0.8030
# Epoch 17/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4307 - accuracy: 0.8016
# Epoch 18/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4218 - accuracy: 0.8041
# Epoch 19/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4240 - accuracy: 0.8006
# Epoch 20/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4211 - accuracy: 0.8105
# Epoch 21/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4265 - accuracy: 0.8033
# Epoch 22/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4185 - accuracy: 0.8045
# Epoch 23/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4163 - accuracy: 0.8140
# Epoch 24/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4128 - accuracy: 0.8099
# Epoch 25/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4055 - accuracy: 0.8181
# Epoch 26/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4134 - accuracy: 0.8129
# Epoch 27/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4007 - accuracy: 0.8177
# Epoch 28/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4041 - accuracy: 0.8152
# Epoch 29/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4071 - accuracy: 0.8189
# Epoch 30/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4118 - accuracy: 0.8081
# Epoch 31/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4007 - accuracy: 0.8195
# Epoch 32/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4046 - accuracy: 0.8160
# Epoch 33/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4073 - accuracy: 0.8167
# Epoch 34/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4110 - accuracy: 0.8153
# Epoch 35/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3974 - accuracy: 0.8223
# Epoch 36/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3984 - accuracy: 0.8207
# Epoch 37/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3987 - accuracy: 0.8169
# Epoch 38/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4039 - accuracy: 0.8148
# Epoch 39/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4102 - accuracy: 0.8155
# Epoch 40/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4018 - accuracy: 0.8230
# Epoch 41/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3853 - accuracy: 0.8215
# Epoch 42/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4039 - accuracy: 0.8152
# Epoch 43/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3959 - accuracy: 0.8222
# Epoch 44/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4046 - accuracy: 0.8131
# Epoch 45/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4063 - accuracy: 0.8121
# Epoch 46/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3957 - accuracy: 0.8204
# Epoch 47/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3923 - accuracy: 0.8210
# Epoch 48/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4039 - accuracy: 0.8116
# Epoch 49/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3930 - accuracy: 0.8228
# Epoch 50/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3973 - accuracy: 0.8163
# Epoch 51/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4016 - accuracy: 0.8191
# Epoch 52/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4017 - accuracy: 0.8142
# Epoch 53/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3863 - accuracy: 0.8242
# Epoch 54/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3922 - accuracy: 0.8236
# Epoch 55/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3855 - accuracy: 0.8246
# Epoch 56/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3898 - accuracy: 0.8285
# Epoch 57/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3878 - accuracy: 0.8254
# Epoch 58/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3945 - accuracy: 0.8222
# Epoch 59/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8197
# Epoch 60/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4038 - accuracy: 0.8159
# Epoch 61/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3875 - accuracy: 0.8250
# Epoch 62/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3884 - accuracy: 0.8235
# Epoch 63/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3874 - accuracy: 0.8255
# Epoch 64/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3932 - accuracy: 0.8250
# Epoch 65/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3981 - accuracy: 0.8180
# Epoch 66/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3999 - accuracy: 0.8193
# Epoch 67/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3919 - accuracy: 0.8194
# Epoch 68/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8172
# Epoch 69/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4008 - accuracy: 0.8218
# Epoch 70/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3855 - accuracy: 0.8244
# Epoch 71/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3860 - accuracy: 0.8251
# Epoch 72/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3907 - accuracy: 0.8210
# Epoch 73/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3950 - accuracy: 0.8234
# Epoch 74/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3913 - accuracy: 0.8243
# Epoch 75/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3981 - accuracy: 0.8191
# Epoch 76/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8262
# Epoch 77/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3864 - accuracy: 0.8275
# Epoch 78/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8170
# Epoch 79/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3951 - accuracy: 0.8222
# Epoch 80/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3864 - accuracy: 0.8288
# Epoch 81/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3917 - accuracy: 0.8217
# Epoch 82/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3912 - accuracy: 0.8230
# Epoch 83/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3896 - accuracy: 0.8247
# Epoch 84/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3933 - accuracy: 0.8180
# Epoch 85/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3880 - accuracy: 0.8271
# Epoch 86/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3859 - accuracy: 0.8243
# Epoch 87/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3818 - accuracy: 0.8261: 0s - loss: 0.3787 -
# Epoch 88/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3982 - accuracy: 0.8201
# Epoch 89/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3916 - accuracy: 0.8266
# Epoch 90/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3838 - accuracy: 0.8287
# Epoch 91/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3877 - accuracy: 0.8227
# Epoch 92/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3919 - accuracy: 0.8224
# Epoch 93/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3830 - accuracy: 0.8292
# Epoch 94/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3971 - accuracy: 0.8193
# Epoch 95/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3842 - accuracy: 0.8298
# Epoch 96/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3954 - accuracy: 0.8202
# Epoch 97/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3934 - accuracy: 0.8189
# Epoch 98/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3853 - accuracy: 0.8258
# Epoch 99/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3881 - accuracy: 0.8254
# Epoch 100/100
# 345/345 [==============================] - 1s 2ms/step - loss: 0.3904 - accuracy: 0.8227

# %%
model.evaluate(X_test, y_test)
# Out:
# 87/87 [==============================] - 0s 1ms/step - loss: 0.4065 - accuracy: 0.8157
# [0.4064657986164093, 0.815674901008606]

# %%
Y_prediction = model.predict(X_test)
Y_prediction[:5]
# Out:
# array([[0.8177707 ],
#        [0.93398154],
#        [0.10575232],
#        [0.9947251 ],
#        [0.16069722]], dtype=float32)

# %% [markdown]
# **So, It gives prediction between 0 to 1 values. Let's take any value which is greater than 0.5,it would be 1 and any value falls less than 0.5, will put 0 instead.**

# %%
Y_Predict_values = []

for ele in Y_prediction:
    if ele > 0.5:
        Y_Predict_values.append(1)
    else:
        Y_Predict_values.append(0)

# %%
Y_Predict_values[:5]
# Out:
# [1, 1, 0, 1, 0]

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test, Y_Predict_values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.82      1352
#            1       0.83      0.80      0.82      1404
#
#     accuracy                           0.82      2756
#    macro avg       0.82      0.82      0.82      2756
# weighted avg       0.82      0.82      0.82      2756

# %%
cm = tf.math.confusion_matrix(labels=y_test, predictions=Y_Predict_values)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(66.5, 0.5, 'Truth')

# %% [markdown]
# **We can see Model Predicts Good, although there are some points where it didn't predicts well.**

# %% [markdown]
# # If you like my work please Upvote me..

# %% [markdown]
# # Thank You..
